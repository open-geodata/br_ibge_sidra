# %% [markdown]
# <br>
#
# # SIDRA

# %%
#!pip install -U sidrapy

# %%
table = 6579
periodo = None
cod_ibge = 3304557
variaveis = 'allxp'
p = 'all' # Periodo
casas_decimais = 's'
header = 'y'

# %%
'dd' if periodo is None else ''
# Out:
# 'dd'

# %%
url = 'https://apisidra.ibge.gov.br/values/{}/{}/{}/{}/{}/{}'.format(
    't/{}'.format(table), # Tabela
    'n6/{}'.format(cod_ibge), # Código IBGE
    'v/{}'.format(variaveis), # Variáveis
    'p/{}'.format(p), # Período
    'd/{}'.format(casas_decimais), # Casas Decimais
    'h/{}'.format(header) # Header
)
url
# Out:
# 'https://apisidra.ibge.gov.br/values/t/6579/n6/3304557/v/allxp/p/all/d/s/h/y'

# %%
r = requests.get(url)
df = pd.DataFrame(r.json())

df.columns = df.iloc[0]
df.drop(df.index[0], inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
# 0  Nível Territorial (Código) Nível Territorial Unidade de Medida (Código)  \
# 0                           6         Município                         45
# 1                           6         Município                         45
# 2                           6         Município                         45
# 3                           6         Município                         45
# 4                           6         Município                         45
# 5                           6         Município                         45
# 6                           6         Município                         45
# 7                           6         Município                         45
# 8                           6         Município                         45
# 9                           6         Município                         45
# 10                          6         Município                         45
# 11                          6         Município                         45
# 12                          6         Município                         45
# 13                          6         Município                         45
# 14                          6         Município                         45
# 15                          6         Município                         45
# 16                          6         Município                         45
# 17                          6         Município                         45
# 18                          6         Município                         45
#
# 0  Unidade de Medida    Valor Município (Código)            Município  \
# 0            Pessoas  5897485            3304557  Rio de Janeiro (RJ)
# 1            Pessoas  5937253            3304557  Rio de Janeiro (RJ)
# 2            Pessoas  5974081            3304557  Rio de Janeiro (RJ)
# 3            Pessoas  6051399            3304557  Rio de Janeiro (RJ)
# 4            Pessoas  6094183            3304557  Rio de Janeiro (RJ)
# 5            Pessoas  6136652            3304557  Rio de Janeiro (RJ)
# 6            Pessoas  6161047            3304557  Rio de Janeiro (RJ)
# 7            Pessoas  6186710            3304557  Rio de Janeiro (RJ)
# 8            Pessoas  6355949            3304557  Rio de Janeiro (RJ)
# 9            Pessoas  6390290            3304557  Rio de Janeiro (RJ)
# 10           Pessoas  6429923            3304557  Rio de Janeiro (RJ)
# 11           Pessoas  6453682            3304557  Rio de Janeiro (RJ)
# 12           Pessoas  6476631            3304557  Rio de Janeiro (RJ)
# 13           Pessoas  6498837            3304557  Rio de Janeiro (RJ)
# 14           Pessoas  6520266            3304557  Rio de Janeiro (RJ)
# 15           Pessoas  6688927            3304557  Rio de Janeiro (RJ)
# 16           Pessoas  6718903            3304557  Rio de Janeiro (RJ)
# 17           Pessoas  6747815            3304557  Rio de Janeiro (RJ)
# 18           Pessoas  6775561            3304557  Rio de Janeiro (RJ)
#
# 0  Variável (Código)                      Variável Ano (Código)   Ano
# 0               9324  População residente estimada         2001  2001
# 1               9324  População residente estimada         2002  2002
# 2               9324  População residente estimada         2003  2003
# 3               9324  População residente estimada         2004  2004
# 4               9324  População residente estimada         2005  2005
# 5               9324  População residente estimada         2006  2006
# 6               9324  População residente estimada         2008  2008
# 7               9324  População residente estimada         2009  2009
# 8               9324  População residente estimada         2011  2011
# 9               9324  População residente estimada         2012  2012
# 10              9324  População residente estimada         2013  2013
# 11              9324  População residente estimada         2014  2014
# 12              9324  População residente estimada         2015  2015
# 13              9324  População residente estimada         2016  2016
# 14              9324  População residente estimada         2017  2017
# 15              9324  População residente estimada         2018  2018
# 16              9324  População residente estimada         2019  2019
# 17              9324  População residente estimada         2020  2020
# 18              9324  População residente estimada         2021  2021

# %%
id_ibge = 3548500
url = 'https://apisidra.ibge.gov.br/values/t/6579/n6/{}/v/all/p/last'.format(id_ibge)

r = requests.get(url)
df = pd.DataFrame(r.json())

df.columns = df.iloc[0]
df.drop(df.index[0], inplace=True)
df.reset_index(inplace=True, drop=True)

# Results
display(df.head())
int(df['Valor'])
# Out:
# 0 Nível Territorial (Código) Nível Territorial Unidade de Medida (Código)  \
# 0                          6         Município                         45
#
# 0 Unidade de Medida   Valor Município (Código)    Município Variável (Código)  \
# 0           Pessoas  433991            3548500  Santos (SP)              9324
#
# 0                      Variável Ano (Código)   Ano
# 0  População residente estimada         2021  2021
# 433991
